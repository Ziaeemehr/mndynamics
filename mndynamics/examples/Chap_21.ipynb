# %% [markdown]
# #### [Chapter 21](https://github.com/Ziaeemehr/mndynamics/blob/main/mndynamics/examples/Chap_21.ipynb)
# <!-- - [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Ziaeemehr/mndynamics/main?labpath=mndynamics%2Fexamples%2FChap_21.ipynb) -->
#
# **Gap Junctions**
#
# - Börgers, C., 2017. An introduction to modeling neuronal dynamics (Vol. 66). Berlin: Springer.
#
# Code by : Abolfazl Ziaeemehr ([GitHub](https://github.com/Ziaeemehr))
#
# <a href="https://colab.research.google.com/github/Ziaeemehr/mndynamics/blob/main/mndynamics/examples/Chap_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# uncomment and run this line to install the package in colab
# !pip install "git+https://github.com/Ziaeemehr/mndynamics.git"

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['figure.figsize'] = [7, 5]

# %%
# [WB_NETWORK_WITH_GJ]
from mndynamics.models.py.WB_Base import WB_Net_GJ

par = {'adj': np.array([[0, 1], [1, 0]]),
       'i_ext': [1.0, 0.0],
       'v0': [-63.0, -63.0],}

obj = WB_Net_GJ(par)
obj()
# Out:
# Wang-Buzsaki Model on Network with Gap junctions
# {'c': 1.0,
#  'g_k': 9.0,
#  'g_na': 35.0,
#  'g_l': 0.1,
#  'v_k': -90.0,
#  'v_na': 55.0,
#  'v_l': -65.0,
#  'i_ext': [1.0, 0.0],
#  't_end': 200.0,
#  'v_thr': -55.0,
#  'v0': [-63.0, -63.0],
#  'dt': 0.01,
#  'g_gap': 0.01,
#  'adj': array([[0, 1],
#         [1, 0]]),
#  'N': 2}

# %%
data = obj.simulate()
t = data['t']
v = data['v']

# %%
fig, ax = plt.subplots(2, figsize=(7, 5), sharex=True)
ax[0].plot(t, v[:,0], lw=2, c="k")
ax[1].plot(t, v[:,1], lw=2, c="k")

for i in range(2):
    ax[i].set_xlim(100, max(t))
    ax[i].set_xlabel("time [ms]")
ax[0].set_yticks(range(-100, 100, 50))
ax[0].set_ylabel(r"$v_1$ [mV]")
ax[1].set_ylabel(r"$v_2$ [mV]")
ax[0].set_ylim(-100, 50)
ax[1].set_ylim(-64, -62)
plt.tight_layout()
