# %% [markdown]
# #### [Chapter 22](https://github.com/Ziaeemehr/mndynamics/blob/main/mndynamics/examples/Chap_22.ipynb)
# <!-- - [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Ziaeemehr/mndynamics/main?labpath=mndynamics%2Fexamples%2FChap_22.ipynb) -->
#
# **A Wilson-Cowan Model of an Oscillatory E-I Network**
#
# - Börgers, C., 2017. An introduction to modeling neuronal dynamics (Vol. 66). Berlin: Springer.
#
# Code by : Abolfazl Ziaeemehr ([GitHub](https://github.com/Ziaeemehr))
#
# <a href="https://colab.research.google.com/github/Ziaeemehr/mndynamics/blob/main/mndynamics/examples/Chap_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# uncomment and run this line to install the package in colab
# !pip install "git+https://github.com/Ziaeemehr/mndynamics.git"

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams['font.size'] = 16
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['figure.figsize'] = [7, 5]

# %%
# [WILSON_COWAN_E_AND_I]
from mndynamics.models.py.WC_Base import WC

obj = WC()
obj()
# Out:
# Wilson-Cowan Model
# {'I_E': 20.0,
#  'I_I': 0.0,
#  'w_EE': 1.5,
#  'w_IE': 1.0,
#  'w_EI': 1.0,
#  'w_II': 0.0,
#  'tau_E': 5.0,
#  'tau_I': 10.0,
#  't_end': 300.0,
#  'E0': 50.0,
#  'I0': 10.0,
#  'dt': 0.01}

# %%
data = obj.simulate()
E = data['E']
I = data['I']
t = data['t']

plt.figure(figsize=(7, 3))
plt.plot(t, E, lw=2, c="r", label="E")
plt.plot(t, I, lw=2, c="b", label="I")
plt.xlim(min(t), max(t))
plt.ylim(0, 100)
plt.xlabel("time [ms]", fontsize=14)
plt.ylabel("v [mV]", fontsize=14)
plt.yticks([0, 50, 100])
plt.tick_params(labelsize=14)
plt.tight_layout()
plt.legend(fontsize=14);

# %%
# [WILSON_COWAN_PHASE_PLANE]
from mndynamics.models.py.WC_Base import WC
obj = WC({'t_end':300})
obj.plot_phase_plane();
